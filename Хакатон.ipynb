# %% [markdown]
# <a href="https://colab.research.google.com/github/RomanChentyrev/hacaton/blob/main/%D0%A5%D0%B0%D0%BA%D0%B0%D1%82%D0%BE%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install pandas pyarrow

# %%
import pandas as pd

# %%
user_history = pd.read_parquet('drive/MyDrive/Хакатон_Сбер_2025/user_history.parquet')
user_history
# Out:
#        user_id                           fact_id
# 0            3  a2af256a95eb4c88bab013de7946c884
# 1            3  745aa41da1644e2b8a21191470c5ee07
# 2            3  988d333fb4f34b82b137ef4bc1bc1c1b
# 3            3  3db9f896188b46bf909b59058fdfe10b
# 4            3  6667d25c3ffb400d9aaa9f06a4252cc2
# ...        ...                               ...
# 24995       50  df754d39d34548e19ec77d339286799d
# 24996       50  4efe212cf550434bbcab7d5440dbae41
# 24997       50  f7940c3898c449ab84f5ee022062ef4e
# 24998       50  dd9367ebf08a4feab34c60ab54752398
# 24999       50  8dd16ddea10740f498f64f4441e144ac
#
# [25000 rows x 2 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
facts_db = pd.read_parquet('drive/MyDrive/Хакатон_Сбер_2025/facts_db.parquet')
facts_db = pd.DataFrame(facts_db)

# %%
user_history = pd.DataFrame(user_history)
user_history
# Out:
#        user_id                           fact_id
# 0            3  a2af256a95eb4c88bab013de7946c884
# 1            3  745aa41da1644e2b8a21191470c5ee07
# 2            3  988d333fb4f34b82b137ef4bc1bc1c1b
# 3            3  3db9f896188b46bf909b59058fdfe10b
# 4            3  6667d25c3ffb400d9aaa9f06a4252cc2
# ...        ...                               ...
# 24995       50  df754d39d34548e19ec77d339286799d
# 24996       50  4efe212cf550434bbcab7d5440dbae41
# 24997       50  f7940c3898c449ab84f5ee022062ef4e
# 24998       50  dd9367ebf08a4feab34c60ab54752398
# 24999       50  8dd16ddea10740f498f64f4441e144ac
#
# [25000 rows x 2 columns]

# %%
# user_history.to_excel('user_history.xlsx')

# %%
# facts_db.to_excel('facts_db.xlsx')

# %%
facts_db['category'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1925487921.py in <cell line: 0>()
# ----> 1 facts_db['category'].value_counts()
#
# NameError: name 'facts_db' is not defined

# %%
$ git lfs install
# Out:
#   File "/tmp/ipython-input-591846361.py", line 1
#     $ git lfs install
#     ^
# SyntaxError: invalid syntax
